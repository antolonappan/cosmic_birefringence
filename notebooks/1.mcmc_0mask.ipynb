# %% [markdown]
# # Planck HFI cosmic-birefringence likelihood
# Precompute theory and covariance, run/resume emcee, and plot with GetDist.

# %%
# Run this cell immediately after restarting the kernel, before importing NumPy.
import os
for variable in ('OMP_NUM_THREADS', 'OPENBLAS_NUM_THREADS', 'MKL_NUM_THREADS',
                 'NUMEXPR_NUM_THREADS', 'VECLIB_MAXIMUM_THREADS'):
    os.environ[variable] = '1'

# %cd /global/homes/l/lonappan/workspace/cosmic_birefringence
# %pip install -e . -q
from cosmic_bire import CBlike
config = 'configs/planck_hfi.yml'
# Choose backend='fortran' (OpenMP) or backend='python' (Numba).
lh = CBlike(config, backend='fortran', threads=4)
print('Likelihood backend:', lh.backend)
# Out:
# /global/u2/l/lonappan/workspace/cosmic_birefringence
# Note: you may need to restart the kernel to use updated packages.
# Likelihood backend: fortran

# %% [markdown]
# ## Precompute
# This creates or loads QuickPol-smoothed ΛCDM, ψℓ, and the reference analytic covariance.

# %%
analysis = lh.precompute()
# Out:
# Using existing /global/homes/l/lonappan/pscratch/CBDATA/theory/beam_corrected_lcdm_spectra_100_143_217_353.npy
# Using existing /global/homes/l/lonappan/pscratch/CBDATA/theory/psi_l_sigma15.npy
# Number of alphas: 8
# Using hfi/lfi ps mask with CO. Index: 0
# Importing observed cl. Filename: /global/homes/l/lonappan/pscratch/CBDATA/spectra/raw/cl_mask_percent_0_freq_100_143_217_353.npy
# Importing beam smoothed LCDM cl. Filename: /global/homes/l/lonappan/pscratch/CBDATA/theory/beam_corrected_lcdm_spectra_100_143_217_353.npy
# Loading /global/homes/l/lonappan/pscratch/CBDATA/theory/psi_l_sigma15.npy
# Loading saved covariance matrix. Filename: /global/homes/l/lonappan/pscratch/CBDATA/covariance/cov_bin_cl_hfi_mask_percent_0_100_143_217_353_lmin51_lmax1491.npy

# %% [markdown]
# ## Sample
# `resume=True` appends `nstep` samples to the existing HDF chain. Use at least 26 walkers for the current 13-dimensional model; the YAML default is 32. BLAS stays single-threaded to avoid nesting; the selected likelihood backend controls its own thread count.

# %%
samples = lh.run_sampler(progress=True, resume=True)
samples.shape
# Out:
# Resuming /global/homes/l/lonappan/pscratch/CBDATA/chains/planck_hfi_mask_30.h5 from step 5974
#  18%|█▊        | 18406/100000 [3:19:18<15:44:57,  1.44it/s]

# %% [markdown]
# ## GetDist corner plot

# %%
# Reload automatically if this kernel still holds an older CBlike definition.
import inspect
if 'show' not in inspect.signature(lh.plot_corner).parameters:
    import importlib
    import cosmic_bire.likelihood as likelihood_module
    importlib.reload(likelihood_module)
    lh = likelihood_module.CBlike(config, backend='fortran', threads=4)

corner_plot = lh.plot_corner(show=True)
# Out:
# Loaded 218368 samples directly from /global/homes/l/lonappan/pscratch/CBDATA/chains/planck_hfi_mask_0.h5
# Removed no burn in
# WARNING:root:auto bandwidth for A_2 very small or failed (h=0.0005924585698953394,N_eff=218368.0). Using fallback (h=0.005763691570795785)
# WARNING:root:fine_bins_2D not large enough for optimal density: A_1, A_2
# WARNING:matplotlib.font_manager:findfont: Font family ['STIXGeneral'] not found. Falling back to DejaVu Sans.
# WARNING:matplotlib.font_manager:findfont: Font family ['STIXGeneral'] not found. Falling back to DejaVu Sans.
# WARNING:matplotlib.font_manager:findfont: Font family ['STIXGeneral'] not found. Falling back to DejaVu Sans.
# WARNING:matplotlib.font_manager:findfont: Font family ['STIXGeneral'] not found. Falling back to DejaVu Sans.
# WARNING:matplotlib.font_manager:findfont: Font family ['STIXNonUnicode'] not found. Falling back to DejaVu Sans.
# WARNING:matplotlib.font_manager:findfont: Font family ['STIXNonUnicode'] not found. Falling back to DejaVu Sans.
# WARNING:matplotlib.font_manager:findfont: Font family ['STIXNonUnicode'] not found. Falling back to DejaVu Sans.
# WARNING:matplotlib.font_manager:findfont: Font family ['STIXSizeOneSym'] not found. Falling back to DejaVu Sans.
# WARNING:matplotlib.font_manager:findfont: Font family ['STIXSizeTwoSym'] not found. Falling back to DejaVu Sans.
# WARNING:matplotlib.font_manager:findfont: Font family ['STIXSizeThreeSym'] not found. Falling back to DejaVu Sans.
# WARNING:matplotlib.font_manager:findfont: Font family ['STIXSizeFourSym'] not found. Falling back to DejaVu Sans.
# WARNING:matplotlib.font_manager:findfont: Font family ['STIXSizeFiveSym'] not found. Falling back to DejaVu Sans.
# WARNING:matplotlib.font_manager:findfont: Font family ['cmsy10'] not found. Falling back to DejaVu Sans.
# WARNING:matplotlib.font_manager:findfont: Font family ['cmr10'] not found. Falling back to DejaVu Sans.
# WARNING:matplotlib.font_manager:findfont: Font family ['cmtt10'] not found. Falling back to DejaVu Sans.
# WARNING:matplotlib.font_manager:findfont: Font family ['cmmi10'] not found. Falling back to DejaVu Sans.
# WARNING:matplotlib.font_manager:findfont: Font family ['cmb10'] not found. Falling back to DejaVu Sans.
# WARNING:matplotlib.font_manager:findfont: Font family ['cmss10'] not found. Falling back to DejaVu Sans.
# WARNING:matplotlib.font_manager:findfont: Font family ['cmex10'] not found. Falling back to DejaVu Sans.

# %%
s = lh.getdist_samples()
# Out:
# Removed no burn in

# %%
print(s.getTable(limit=1).tableTex())
# Out:
# WARNING:root:auto bandwidth for A_2 very small or failed (h=0.0005924585698953394,N_eff=218368.0). Using fallback (h=0.005763691570795785)
# \begin{tabular} { l  c}
#
#  Parameter &  68\% limits\\
# \hline
# {\boldmath$\beta          $} & $0.37\pm 0.12              $\\
#
# {\boldmath$\alpha_{100A}  $} & $-0.33\pm 0.14             $\\
#
# {\boldmath$\alpha_{143A}  $} & $0.02\pm 0.12              $\\
#
# {\boldmath$\alpha_{217A}  $} & $-0.07\pm 0.11             $\\
#
# {\boldmath$\alpha_{353A}  $} & $-0.20\pm 0.11             $\\
#
# {\boldmath$\alpha_{100B}  $} & $-0.43\pm 0.13             $\\
#
# {\boldmath$\alpha_{143B}  $} & $0.14\pm 0.12              $\\
#
# {\boldmath$\alpha_{217B}  $} & $-0.09\pm 0.11             $\\
#
# {\boldmath$\alpha_{353B}  $} & $-0.23\pm 0.11             $\\
#
# {\boldmath$A_{0}          $} & $0.036^{+0.010}_{-0.035}   $\\
#
# {\boldmath$A_{1}          $} & $0.0138^{+0.0037}_{-0.014} $\\
#
# {\boldmath$A_{2}          $} & $0.0304^{+0.0093}_{-0.030} $\\
#
# {\boldmath$A_{3}          $} & $0.092^{+0.040}_{-0.072}   $\\
# \hline
# \end{tabular}
